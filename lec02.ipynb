# %% [markdown]
# <a href="https://colab.research.google.com/github/ynomura-dev/cls-ai/blob/main/lec02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # lec02

# %% [markdown]
# ex211

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# ex212

# %%
name = input()
age = input()
print(f"私は{name}です。{age}歳です。")

# %% [markdown]
# ex213

# %%
base = float(input())
height = float(input())
print(base*height/2)

# %% [markdown]
# work211

# %%
name = input()
age = input()

print(f"名前:{name}\n年齢:{age}\n{name}さんは{age}歳です")
# Out:
# namaee
# 123
# 名前:namaee
# 年齢:123
# namaeeさんは123歳です

# %% [markdown]
# ex221

# %%
score = 75
if score >= 60:
    print("合格")
else:
    print("不合格")
# Out:
# 合格

# %% [markdown]
# ex222

# %%
lang = int(input("lang:"))
math = int(input("math:"))
if lang >= 60 and math >= 60:
    print("合格")
else:
    print("不合格")
# Out:
# lang:243
# math:2
# 不合格

# %% [markdown]
# ex223

# %%
a = 8
b = 12

if a > b:
    print(a)
elif b > a:
    print(b)
else:
    print("同じです")
# Out:
# 12

# %% [markdown]
# work221

# %%
score = int(input("Enter your score here\n"))

if score > 80:
  print("優秀")
elif score > 60:
  print("合格")
else:
  print("不合格")
# Out:
# Enter your score here
# 23
# 不合格

# %% [markdown]
# ex231

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ex232

# %%
for i in range(9, 4, -1):
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5

# %% [markdown]
# ex233

# %%
num = 1
while num <= 10:
    if num % 2 == 0:
        print(num)
    num=num+1
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# work231

# %%
sum = 0

for i in range(1, 21):
    if i % 3 == 0:
      sum += i
      print(i)
print(f"sum = {sum}")
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# sum = 63

# %% [markdown]
# ex241

# %%
numbers = []
numbers.append(1)
numbers.append(2)
numbers.append(3)
print(numbers)
# Out:
# [1, 2, 3]

# %% [markdown]
# ex242

# %%
del sum    //work231でsumを整数として代入してしまったので、解除しておく

data = [5, 8, 2, 9]
print("max:", max(data))
print("min:", min(data))
print("sum:", sum(data))
# Out:
# max: 9
# min: 2
# sum: 24

# %% [markdown]
# ex243

# %%
nums = [1, 2, 3, 4, 5]
for n in nums:
    print(n)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# work241

# %%
nums = [10, 20, 30, 40, 50]
for i in range(len(nums)):
  doubled.append(nums[i]*2)
print(doubled)
# Out:
# [20, 40, 60, 80, 100]

# %% [markdown]
# ex251

# %%
def hello(name):
    print(f"hello、{name}さん！")

hello("枚方")
# Out:
# hello、枚方さん！

# %% [markdown]
# ex252

# %%
def add(x, y):
    return x + y

result = add(10, 5)
print("結果:", result)
# Out:
# 結果: 15

# %% [markdown]
# ex253

# %%
def is_even(n):
    return n % 2 == 0

print(is_even(4))  # 偶数
print(is_even(7))  # 奇数
# Out:
# True
# False

# %% [markdown]
# work251

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True



print(is_prime(7))   # 素数
print(is_prime(10))  # 素数ではない
# Out:
# True
# False
